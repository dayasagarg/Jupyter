# %%
import requests
import pandas as pd
response1 = requests.get(
    "https://lendittfinserve.com/prod/admin/dashboard/allDisbursedLoans?start_date=2023-12-16T10%3A00%3A00.000Z&end_date=2023-12-16T10%3A00%3A00.000Z&page=1&download=true")  # Current date
# print(response1.status_code)
# print(response1.json())
data = response1.json()['data']['rows']
# print(data['rows'])
# print(type(response1.json()))
# df = pd.read_json(data)
# print(df)
# df = pd.DataFrame(data)
# df

# %%
data
# Out:
# [{'userId': 'fce6a8b3-273e-4aa9-8a5f-2359e5e5c209',
#   'Loan ID': 699143,
#   'Name': 'Dhanikela Sai',
#   'Phone': '7795709473',
#   'Completed loans': 3,
#   'App platform': 'LENDITT',
#   'Interest Rate': 0.172,
#   'Loan Tenure (Days)': 55,
#   'Approved amount': 16500,
#   'Disbursed Amount': 14568,
#   'Processing fees': 1272,
#   'Document Charges': 165,
#   'Online convenience fees': 200,
#   'Risk assessment fees': 200,
#   'Insurance premium': '-',
#   'Stamp Duty Fees': 0,
#   'GST Amount': 295,
#   'Total Expected Amount': 17678,
#   'Total Interest Amount': 1178,
#   'Total Emi': 2,
#   'Cibil Score': 774,
#   'Pl Score': 687,
#   'Company Name': 'CELSTREAM TECHNOLOGIES PRIVATE LIMITED',
#   'Designation': 'Executive',
#   'Gender': 'MALE',
#   'State': 'karnataka',
#   'Account Number': 50100242151985,
#   'Bank Name': 'HDFC',
#   'Ifsc  Code': 'HDFC0000549',
#   'Mandate Type': 'RAZORPAY',
#   'Disbursement Date': '16-12-2023',
#   'Loan Approved By': 'system',
# ...

# %%
df
# Out:
#                                                     data  message  statusCode  \
# count                                                447  SUCCESS         200
# rows   [{'userId': '3f518ebb-7f82-4a10-bd34-7565fcdd6...  SUCCESS         200
#
#        valid
# count   True
# rows    True

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                    userId  Loan ID                      Name  \
# 0    fce6a8b3-273e-4aa9-8a5f-2359e5e5c209   699143             Dhanikela Sai
# 1    6038287d-5573-4fc5-a9e9-40438435bceb   699142     Kamal Badridatt Joshi
# 2    5bb1544c-b060-4c81-a6b8-3ecec4490b8b   699136       Bireddy Vikas Reddy
# 3    9ed1276d-aa94-481e-9e61-77a713a70c1f   699126  Anurag Nandagopal Tiwari
# 4    2b0a0362-3197-482f-b36b-58110a805647   699116      Rahul Narayanan Nair
# ..                                    ...      ...                       ...
# 248  a87fc032-8334-4d26-af1a-92791ad4e35b   691705           Justin Jose J S
# 249  bc89fe33-daf4-43f3-bf3c-2d4646f19622   691646  Madhuri Bhaskar Sagvekar
# 250  f92f5274-bd35-4503-9838-2880b1e25723   691411       Vikas Maruti Jadhav
# 251  7cd18e13-c8ab-4d57-b2b5-d78cda4663f2   690270              BODAGALA SAI
# 252  65f9c384-6c22-4c3f-82be-061e3a0cea6c   689879               Surat Singh
#
# ...
