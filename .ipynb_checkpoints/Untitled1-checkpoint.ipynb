# %%
import pandas as pd
import requests
response = requests.get("https://lendittfinserve.com/stag/admin/dashboard/allDisbursedLoans?start_date=2023-12-19T10%3A00%3A00.000Z&end_date=2023-12-19T10%3A00%3A00.000Z&page=1&download=true")
data = response.json()['data']['rows']
df = pd.DataFrame(data)
df
# Out:
#                                    userId  Loan ID                   Name  \
# 0    3fba2489-4243-4510-8f50-46e6f157b251   702784       Bojanki Santhosh
# 1    7cd34a7f-4bdd-4386-87ef-4c5bd1e6bac3   702781    Pradeep Kumar Dutta
# 2    48a23b23-5555-4348-ace6-2d7236bd16f2   702769     Abhimanyu Bhardwaj
# 3    8df3442a-9fde-4367-9c24-7ff976f28eb4   702757    Karakavalasa Murali
# 4    392994a0-95d3-48b6-b684-1ac620ba58ac   702756            RAHUL BAFNA
# ..                                    ...      ...                    ...
# 240  6c838bea-dbb4-4beb-85d2-b5f17be99af6   695099       Christian Prince
# 241  b6417a77-9089-43eb-9253-ba28f6620ac5   694956               Rajashri
# 242  ea2e9260-8f77-4251-b705-1fd863ac20c6   694101  Tummal Bharat Bhushan
# 243  931b34a5-9860-4c4e-93aa-4cf087d4989d   694093           Rishabh Rana
# 244  4557c183-6397-4939-80c9-0afbb778548d   692733         Sudhakar Manda
#
#           Phone  Completed loans App platform  Interest Rate  \
# ...

# %%
df["Disbursed Amount"].mean()
# Out:
# 18071.412244897958

# %%
df["Disbursed Amount"].max()
# Out:
# 45103

# %%
df["Disbursed Amount"].min()
# Out:
# 4086

# %%
from pyspark.sql import SparkSession

# %%
# !pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/316.9 MB ? eta -:--:--
#      -------------------------------------- 0.0/316.9 MB 487.6 kB/s eta 0:10:50
#      ---------------------------------------- 0.1/316.9 MB 1.1 MB/s eta 0:04:51
#      ---------------------------------------- 0.2/316.9 MB 1.5 MB/s eta 0:03:32
#      ---------------------------------------- 0.5/316.9 MB 2.2 MB/s eta 0:02:26
#      ---------------------------------------- 0.7/316.9 MB 3.1 MB/s eta 0:01:44
#      ---------------------------------------- 0.7/316.9 MB 3.1 MB/s eta 0:01:44
#      ---------------------------------------- 1.3/316.9 MB 3.7 MB/s eta 0:01:27
#      ---------------------------------------- 1.6/316.9 MB 4.1 MB/s eta 0:01:17
#      ---------------------------------------- 1.8/316.9 MB 4.3 MB/s eta 0:01:14
#      ---------------------------------------- 2.0/316.9 MB 4.1 MB/s eta 0:01:18
# ...

# %%
from pyspark.sql import SparkSession
# spark = SparkSession.builder.appName("data").getOrCreate()

# %%
spark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 spark
#
# NameError: name 'spark' is not defined

# %%
from pyspark.sql import SparkSession
# spark = SparkSession.builder.appName("df").getOrCreate()

# %%
spark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 spark
#
# NameError: name 'spark' is not defined
